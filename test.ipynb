# %%
class lopcha:
    def __init__(self, name, age, email):
        self.name = name
        self.age = age
        self.email = email

class lopcon1(lopcha):
    def __init__(self, name, age):
        super().__init__(name, age)

class lopcon2(lopcha):
    def __init__(self, name, age):
        super().__init__(name, age)

# %%
class lopcon1:
    def __init__(self, name, age, email):
        self.name = name
        self.age = age
        self.email = email

class lopcon2:
    def __init__(self, name, age, email):
        self.name = name
        self.age = age
        self.email = email
